# %%
import gspread
import yaml
from oauth2client.service_account import ServiceAccountCredentials

# %%
scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('../puma-client.json', scope)
client = gspread.authorize(creds)

# %%
sheet = client.open("PuMA Units + SIMS").sheet1

# %%
units = sheet.col_values(6)
stoveTypes = sheet.col_values(5)
lat = sheet.col_values(15)
long = sheet.col_values(16)
header = [units[0], stoveTypes[0], lat[0], long[0]]

#print(header)
#print(units)
# Out:
# ['Unit', 'Stove Type', 'Latitude', 'Longitude']
# ['Unit', 'FBK000', 'FBK001', 'FBK002', 'FBK003', 'FBK004', 'FBK005', 'FBK006', 'FBK007', 'FBK008', 'FBK009', 'FBK010', 'FBK011', 'FBK013', 'FBK012', 'FBK014', 'FBK015', 'FBK017', 'FBK018', 'FBK016', 'FBK019', 'FBK020', 'FBK021', 'FBK022', 'FBK023', 'FBK024', 'FBK025', 'FBK026', 'FBK027', 'FBK028', 'FBK029', 'FBK030', 'FBK031', 'FBK032', 'FBK033', 'FBK034', 'FBK035', 'FBK036', 'FBK037', 'FBK038', 'FBK039', 'FBK040', 'FBK041', 'FBK042', 'FBK043', 'FBK044', 'FBK045', 'ATV000']

# %%
inventory = {}
for i in range(1, len(units)):
    inventory[units[i]] = {"Stove Type": stoveTypes[i], "Location": [float(lat[i]), float(long[i])]}

#print(inventory)
# Out:
# {'FBK000': {'Stove Type': 'Laser 73/730', 'Location': [64.87628, -147.84861]}, 'FBK001': {'Stove Type': 'Laser 56/560', 'Location': [64.86001, -147.913]}, 'FBK002': {'Stove Type': 'M2200', 'Location': [64.85885, -147.962]}, 'FBK003': {'Stove Type': 'Laser 56/560', 'Location': [64.90049, -147.773]}, 'FBK004': {'Stove Type': 'Laser 73/730', 'Location': [64.89163, -147.674]}, 'FBK005': {'Stove Type': 'Laser 56/560', 'Location': [64.8487, -147.968]}, 'FBK006': {'Stove Type': 'Laser 73/730', 'Location': [64.79955, -148.063]}, 'FBK007': {'Stove Type': 'Laser 73/730', 'Location': [64.91331, -147.602]}, 'FBK008': {'Stove Type': 'Laser 73/730', 'Location': [64.8496, -147.715]}, 'FBK009': {'Stove Type': 'Laser 73/730', 'Location': [64.57072, -147.045]}, 'FBK010': {'Stove Type': 'Laser 56/560', 'Location': [64.92074, -147.918]}, 'FBK011': {'Stove Type': 'Laser 56/560', 'Location': [64.77877, -148.04]}, 'FBK013': {'Stove Type': 'Laser 73/730', 'Location': [64.96401, -147.755]}, 'FBK012': {'Stove Type': 'Laser 73/730', 'Location': [64.78514, -148.034]}, 'FBK014': {'Stove Type': 'M441', 'Location': [64.83723, -148.027]}, 'FBK015': {'Stove Type': 'M422', 'Location': [64.83723, -148.027]}, 'FBK017': {'Stove Type': 'Laser 73/730', 'Location': [64.81606, -148.002]}, 'FBK018': {'Stove Type': 'Laser 73/730', 'Location': [64.81606, -148.002]}, 'FBK016': {'Stove Type': 'Laser 530', 'Location': [64.76378, -148.083]}, 'FBK019': {'Stove Type': 'M441', 'Location': [64.87386, -147.813]}, 'FBK020': {'Stove Type': 'M422', 'Location': [64.87386, -147.813]}, 'FBK021': {'Stove Type': 'M2200', 'Location': [64.85657, -147.893]}, 'FBK022': {'Stove Type': 'Laser 530', 'Location': [64.78939, -148.07]}, 'FBK023': {'Stove Type': 'Laser 530', 'Location': [64.8388, -148.064]}, 'FBK024': {'Stove Type': 'Laser 730', 'Location': [64.92216, -147.931]}, 'FBK025': {'Stove Type': 'Laser 530', 'Location': [64.92216, -147.931]}, 'FBK026': {'Stove Type': 'Laser 56/560', 'Location': [64.9112, -147.879]}, 'FBK027': {'Stove Type': 'Laser 73/730', 'Location': [64.89892, -147.738]}, 'FBK028': {'Stove Type': 'Laser 73/730', 'Location': [64.77966, -148.058]}, 'FBK029': {'Stove Type': 'Laser 530', 'Location': [64.91823, -147.868]}, 'FBK030': {'Stove Type': 'M422', 'Location': [64.8601, -147.895]}, 'FBK031': {'Stove Type': 'Laser 56/560', 'Location': [64.8873, -147.475]}, 'FBK032': {'Stove Type': 'Laser 56/560', 'Location': [64.80488, -148.07]}, 'FBK033': {'Stove Type': 'M2200', 'Location': [64.90272, -147.772]}, 'FBK034': {'Stove Type': 'Laser 73/730', 'Location': [64.87842, -147.413]}, 'FBK035': {'Stove Type': 'Laser 73/730', 'Location': [64.89301, -147.831]}, 'FBK036': {'Stove Type': 'Laser 73/730', 'Location': [64.79853, -148.075]}, 'FBK037': {'Stove Type': 'Laser 56/560', 'Location': [64.86302, -147.888]}, 'FBK038': {'Stove Type': 'Laser 73/730', 'Location': [64.90147, -147.72]}, 'FBK039': {'Stove Type': 'Laser 73/730', 'Location': [64.89185, -147.755]}, 'FBK040': {'Stove Type': 'Laser 73/730', 'Location': [64.84648, -147.826]}, 'FBK041': {'Stove Type': 'Laser 56/560', 'Location': [64.90553, -147.879]}, 'FBK042': {'Stove Type': 'Laser 56/560', 'Location': [64.86369, -147.67]}, 'FBK043': {'Stove Type': 'Laser 73/730', 'Location': [64.83624, -147.929]}, 'FBK044': {'Stove Type': 'Laser 73/730', 'Location': [64.80454, -147.449]}, 'FBK045': {'Stove Type': 'Laser 73/730', 'Location': [64.89274, -147.743]}, 'ATV000': {'Stove Type': 'M422', 'Location': [0.0, 0.0]}}

# %%
print(yaml.dump(inventory))
# Out:
# ATV000:
#   Location:
#   - 0.0
#   - 0.0
#   Stove Type: M422
# FBK000:
#   Location:
#   - 64.87628
#   - -147.84861
#   Stove Type: Laser 73/730
# FBK001:
#   Location:
#   - 64.86001
#   - -147.913
#   Stove Type: Laser 56/560
# FBK002:
#   Location:
#   - 64.85885
#   - -147.962
#   Stove Type: M2200
# FBK003:
#   Location:
#   - 64.90049
#   - -147.773
#   Stove Type: Laser 56/560
# FBK004:
#   Location:
#   - 64.89163
#   - -147.674
#   Stove Type: Laser 73/730
# FBK005:
#   Location:
#   - 64.8487
#   - -147.968
#   Stove Type: Laser 56/560
# FBK006:
#   Location:
#   - 64.79955
#   - -148.063
#   Stove Type: Laser 73/730
# FBK007:
#   Location:
#   - 64.91331
#   - -147.602
#   Stove Type: Laser 73/730
# FBK008:
#   Location:
#   - 64.8496
#   - -147.715
#   Stove Type: Laser 73/730
# FBK009:
#   Location:
#   - 64.57072
#   - -147.045
#   Stove Type: Laser 73/730
# FBK010:
#   Location:
#   - 64.92074
#   - -147.918
#   Stove Type: Laser 56/560
# FBK011:
#   Location:
#   - 64.77877
#   - -148.04
#   Stove Type: Laser 56/560
# FBK012:
#   Location:
#   - 64.78514
#   - -148.034
#   Stove Type: Laser 73/730
# FBK013:
#   Location:
#   - 64.96401
#   - -147.755
#   Stove Type: Laser 73/730
# FBK014:
#   Location:
#   - 64.83723
#   - -148.027
#   Stove Type: M441
# FBK015:
#   Location:
#   - 64.83723
#   - -148.027
#   Stove Type: M422
# FBK016:
#   Location:
#   - 64.76378
#   - -148.083
#   Stove Type: Laser 530
# FBK017:
#   Location:
#   - 64.81606
#   - -148.002
#   Stove Type: Laser 73/730
# FBK018:
#   Location:
#   - 64.81606
#   - -148.002
#   Stove Type: Laser 73/730
# FBK019:
#   Location:
#   - 64.87386
#   - -147.813
#   Stove Type: M441
# FBK020:
#   Location:
#   - 64.87386
#   - -147.813
#   Stove Type: M422
# FBK021:
#   Location:
#   - 64.85657
#   - -147.893
#   Stove Type: M2200
# FBK022:
#   Location:
#   - 64.78939
#   - -148.07
#   Stove Type: Laser 530
# FBK023:
#   Location:
#   - 64.8388
#   - -148.064
#   Stove Type: Laser 530
# FBK024:
#   Location:
#   - 64.92216
#   - -147.931
#   Stove Type: Laser 730
# FBK025:
#   Location:
#   - 64.92216
#   - -147.931
#   Stove Type: Laser 530
# FBK026:
#   Location:
#   - 64.9112
#   - -147.879
#   Stove Type: Laser 56/560
# FBK027:
#   Location:
#   - 64.89892
#   - -147.738
#   Stove Type: Laser 73/730
# FBK028:
#   Location:
#   - 64.77966
#   - -148.058
#   Stove Type: Laser 73/730
# FBK029:
#   Location:
#   - 64.91823
#   - -147.868
#   Stove Type: Laser 530
# FBK030:
#   Location:
#   - 64.8601
#   - -147.895
#   Stove Type: M422
# FBK031:
#   Location:
#   - 64.8873
#   - -147.475
#   Stove Type: Laser 56/560
# FBK032:
#   Location:
#   - 64.80488
#   - -148.07
#   Stove Type: Laser 56/560
# FBK033:
#   Location:
#   - 64.90272
#   - -147.772
#   Stove Type: M2200
# FBK034:
#   Location:
#   - 64.87842
#   - -147.413
#   Stove Type: Laser 73/730
# FBK035:
#   Location:
#   - 64.89301
#   - -147.831
#   Stove Type: Laser 73/730
# FBK036:
#   Location:
#   - 64.79853
#   - -148.075
#   Stove Type: Laser 73/730
# FBK037:
#   Location:
#   - 64.86302
#   - -147.888
#   Stove Type: Laser 56/560
# FBK038:
#   Location:
#   - 64.90147
#   - -147.72
#   Stove Type: Laser 73/730
# FBK039:
#   Location:
#   - 64.89185
#   - -147.755
#   Stove Type: Laser 73/730
# FBK040:
#   Location:
#   - 64.84648
#   - -147.826
#   Stove Type: Laser 73/730
# FBK041:
#   Location:
#   - 64.90553
#   - -147.879
#   Stove Type: Laser 56/560
# FBK042:
#   Location:
#   - 64.86369
#   - -147.67
#   Stove Type: Laser 56/560
# FBK043:
#   Location:
#   - 64.83624
#   - -147.929
#   Stove Type: Laser 73/730
# FBK044:
#   Location:
#   - 64.80454
#   - -147.449
#   Stove Type: Laser 73/730
# FBK045:
#   Location:
#   - 64.89274
#   - -147.743
#   Stove Type: Laser 73/730

# %%
file = open('../puma-inventory.yml', 'w')
file.write(yaml.dump(inventory))
file.close()
