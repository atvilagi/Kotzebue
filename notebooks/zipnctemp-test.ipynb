# %%
from netCDF4 import Dataset, MFDataset, num2date
import pandas as pd
import numpy as np
from zipfile import ZipFile
import matplotlib.pyplot as plt
import matplotlib as ply
from datetime import datetime

# %%
archive = ZipFile("../data/SensorNetcdfOutput.zip",'r')
print(archive.namelist())
nc_data = archive.open('air_temperature.nc')
# Dataset(nc_data) # failed to work :()
at_data = Dataset("../data/air_temperature.nc")
at_data
# Out:
# ['air_temperature.nc', 'metadata.txt']
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     Conventions: CF-1.6
#     Metadata_Conventions: Unidata Dataset Discovery v1.0
#     featureType: timeSeries
#     cdm_data_type: Station
#     nodc_template_version: NODC_NetCDF_TimeSeries_Orthogonal_Template_v1.0
#     standard_name_vocabulary: CF-1.6
#     platform: platform
#     instrument: instrument
#     title: urn:ioos:sensor:gov.usda.nrcs.wcc.snotel:1174:air_temperature
#     summary: Sensor observations for urn:ioos:sensor:gov.usda.nrcs.wcc.snotel:1174:air_temperature, feature type timeSeries
#     processing_level: none
#     date_created: 2019-05-17T18:34:39.039Z
#     license: Freely Distributed
#     id: 1174
#     naming_authority: gov.usda.nrcs.wcc.snotel
#     keywords: SnoTel,Fairbanks F.O.,air_temperature
#     institution: SnoTel
#     acknowledgement:
#     contributor_role: operator
#     contributor_name: SnoTel
#     publisher_name: SnoTel
#     publisher_email: tony.tolsdorf@por.usda.gov
#     publisher_url: http://www.wcc.nrcs.usda.gov/snow/
#     provider_name: SnoTel
#     provider_email: tony.tolsdorf@por.usda.gov
#     provider_url: http://www.wcc.nrcs.usda.gov/snow/
#     geospatial_lat_min: 64.855
#     geospatial_lat_max: 64.855
#     geospatial_lat_units: degrees_north
#     geospatial_lon_min: -147.795
#     geospatial_lon_max: -147.795
#     geospatial_lon_units: degrees_east
#     time_coverage_start: 2015-05-05T15:00:00.000Z
#     time_coverage_end: 2019-05-17T16:00:00.000Z
#     dimensions(sizes): time(33548), feature_type_instance(46)
#     variables(dimensions): |S1 feature_type_instance(feature_type_instance), int32 crs(), float64 time(time), float64 latitude(), float64 longitude(), float64 height(), int32 platform(), int32 air_temperature_instrument(), float64 air_temperature(time)
#     groups:

# %%
airtemp = at_data.variables['air_temperature']
plt.plot(airtemp)

# %%
print(type(at_data.variables['time'][:]))

at = pd.DataFrame(at_data.variables['air_temperature'][:],
                  at_data.variables['time'][:])
plt.plot(at)
# Out:
# <class 'numpy.ma.core.MaskedArray'>
